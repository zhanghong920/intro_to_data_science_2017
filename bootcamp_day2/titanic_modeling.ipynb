# %% [markdown]
# # Titanic modeling

# %% [markdown]
# ## Split dataset

# %%
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %% [markdown]
# ## Fit a tree model

# %%
# http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# try other kind of tree model if you have time

# %% [markdown]
# ## Parameter tuning

# %%
# http://scikit-learn.org/stable/modules/grid_search.html

# %% [markdown]
# ## Train validation error

# %%
# visualize train validation error of different parameters

# %% [markdown]
# ## Evaluate on testset

# %%
# how is your result?

# %% [markdown]
# ### What are the matrices aproporate for classifier evaluation?

# %%
# Understand Accuracy, AUC (ROC), Precision and Recall
