# %%
% matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
print('Pandas:', pd.__version__)  #check your env
print('Numpy:',np.__version__)
print('Matplotlib:', matplotlib. __version__)
# Out:
# Pandas: 0.20.1
# Numpy: 1.12.1
# Matplotlib: 2.0.2

# %%
 df = pd.read_csv('https://raw.githubusercontent.com/eclarson/DataMiningNotebooks/master/data/titanic.csv') #read dataset

# %%
df_train #look through the whole data
# Out:
#      Survived   Age  SibSp  Parch      Fare  dummy_Q  dummy_C  dummy_male  \
# 6           0  54.0      0      0   51.8625        0        0           1
# 718         0  28.0      0      0   15.5000        1        0           1
# 685         0  25.0      1      2   41.5792        0        1           1
# 73          0  26.0      1      0   14.4542        0        1           1
# 882         0  22.0      0      0   10.5167        0        0           0
# 328         1  31.0      1      1   20.5250        0        0           0
# 453         1  49.0      1      0   89.1042        0        1           1
# 145         0  19.0      1      1   36.7500        0        0           1
# 234         0  24.0      0      0   10.5000        0        0           1
# 220         1  16.0      0      0    8.0500        0        0           1
# 370         1  25.0      1      0   55.4417        0        1           1
# 811         0  39.0      0      0   24.1500        0        0           1
# 132         0  47.0      1      0   14.5000        0        0           0
# 694         0  60.0      0      0   26.5500        0        0           1
# 864         0  24.0      0      0   13.0000        0        0           1
# 185         0  28.0      0      0   50.0000        0        0           1
# 41          0  27.0      1      0   21.0000        0        0           0
# 547         1  28.0      0      0   13.8625        0        1           1
# 108         0  38.0      0      0    7.8958        0        0           1
# 603         0  44.0      0      0    8.0500        0        0           1
# 56          1  21.0      0      0   10.5000        0        0           0
# 394         1  24.0      0      2   16.7000        0        0           0
# 706         1  45.0      0      0   13.5000        0        0           0
# 549         1   8.0      1      1   36.7500        0        0           1
# 24          0   8.0      3      1   21.0750        0        0           0
# 351         0  28.0      0      0   35.0000        0        0           1
# 429         1  32.0      0      0    8.0500        0        0           1
# 434         0  50.0      1      0   55.9000        0        0           1
# 51          0  21.0      0      0    7.8000        0        0           1
# 526         1  50.0      0      0   10.5000        0        0           0
# ..        ...   ...    ...    ...       ...      ...      ...         ...
# 276         0  45.0      0      0    7.7500        0        0           0
# 191         0  19.0      0      0   13.0000        0        0           1
# 385         0  18.0      0      0   73.5000        0        0           1
# 805         0  31.0      0      0    7.7750        0        0           1
# 413         0  28.0      0      0    0.0000        0        0           1
# 491         0  21.0      0      0    7.2500        0        0           1
# 343         0  25.0      0      0   13.0000        0        0           1
# 769         0  32.0      0      0    8.3625        0        0           1
# 308         0  30.0      1      0   24.0000        0        1           1
# 661         0  40.0      0      0    7.2250        0        1           1
# 130         0  33.0      0      0    7.8958        0        1           1
# 663         0  36.0      0      0    7.4958        0        0           1
# 871         1  47.0      1      1   52.5542        0        0           0
# 99          0  34.0      1      0   26.0000        0        0           1
# 372         0  19.0      0      0    8.0500        0        0           1
# 87          0  28.0      0      0    8.0500        0        0           1
# 458         1  50.0      0      0   10.5000        0        0           0
# 330         1  28.0      2      0   23.2500        1        0           0
# 214         0  28.0      1      0    7.7500        1        0           1
# 466         0  28.0      0      0    0.0000        0        0           1
# 121         0  28.0      0      0    8.0500        0        0           1
# 614         0  35.0      0      0    8.0500        0        0           1
# 20          0  35.0      0      0   26.0000        0        0           1
# 700         1  18.0      1      0  227.5250        0        1           0
# 71          0  16.0      5      2   46.9000        0        0           0
# 106         1  21.0      0      0    7.6500        0        0           0
# 270         0  28.0      0      0   31.0000        0        0           1
# 860         0  41.0      2      0   14.1083        0        0           1
# 435         1  14.0      1      2  120.0000        0        0           0
# 102         0  21.0      0      1   77.2875        0        0           1
#
#      dummy_1  dummy_S  dummy_3  dummy_2  dummy_female
# 6          1        1        0        0             0
# 718        0        0        1        0             0
# 685        0        0        0        1             0
# 73         0        0        1        0             0
# 882        0        1        1        0             1
# 328        0        1        1        0             1
# 453        1        0        0        0             0
# 145        0        1        0        1             0
# 234        0        1        0        1             0
# 220        0        1        1        0             0
# 370        1        0        0        0             0
# 811        0        1        1        0             0
# 132        0        1        1        0             1
# 694        1        1        0        0             0
# 864        0        1        0        1             0
# 185        1        1        0        0             0
# 41         0        1        0        1             1
# 547        0        0        0        1             0
# 108        0        1        1        0             0
# 603        0        1        1        0             0
# 56         0        1        0        1             1
# 394        0        1        1        0             1
# 706        0        1        0        1             1
# 549        0        1        0        1             0
# 24         0        1        1        0             1
# 351        1        1        0        0             0
# 429        0        1        1        0             0
# 434        1        1        0        0             0
# 51         0        1        1        0             0
# 526        0        1        0        1             1
# ..       ...      ...      ...      ...           ...
# 276        0        1        1        0             1
# 191        0        1        0        1             0
# 385        0        1        0        1             0
# 805        0        1        1        0             0
# 413        0        1        0        1             0
# 491        0        1        1        0             0
# 343        0        1        0        1             0
# 769        0        1        1        0             0
# 308        0        0        0        1             0
# 661        0        0        1        0             0
# 130        0        0        1        0             0
# 663        0        1        1        0             0
# 871        1        1        0        0             1
# 99         0        1        0        1             0
# 372        0        1        1        0             0
# 87         0        1        1        0             0
# 458        0        1        0        1             1
# 330        0        0        1        0             1
# 214        0        0        1        0             0
# 466        0        1        0        1             0
# 121        0        1        1        0             0
# 614        0        1        1        0             0
# 20         0        1        0        1             0
# 700        1        0        0        0             1
# 71         0        1        1        0             1
# 106        0        1        1        0             1
# 270        1        1        0        0             0
# 860        0        1        1        0             0
# 435        1        1        0        0             1
# 102        1        1        0        0             0
#
# [596 rows x 13 columns]

# %%
df_droped=df.drop(['PassengerId','Name','Cabin','Ticket'],axis=1) #Drop the variables conldn't be used

# %%
df_droped['Pclass'] = df_droped['Pclass'].astype('str') #Transfer Pclass to string for dummy

# %%
df_dummy = pd.get_dummies(df_droped[["Pclass","Sex","Embarked"]]) #Get dummy variables for charater variables(Pclass is not necessary)

# %%
head = list(set(df_dummy.columns)) #merge dummies and original variables
#df_droped = pd.merge(df_droped,df_dummy)
df_droped[head] = df_dummy[head]

# %%
df_droped=df_droped.drop(["Pclass","Sex","Embarked"],axis=1) #Drop variables have dummied

# %%
func = lambda grp: grp.fillna(grp.median()) #Use transform func to impute NaN
df_imputed = df_droped.transform(func)
col_deleted = list( set(df_droped.columns) - set(df_imputed.columns)) 
df_imputed[col_deleted] = df_droped[col_deleted]

# %%
>>> from sklearn.model_selection import train_test_split #split to train and test set
df_train, df_test = train_test_split(df_imputed,test_size=0.33)

# %%
target_train = df_train['Survived'] #Get the target variables and Drop it from train dataset
target_test = df_test['Survived']
df_train=df_train.drop(["Survived"],axis=1)
df_test=df_test.drop(["Survived"],axis=1)

# %%
target_test
# Out:
# 770    0
# 626    0
# 110    0
# 107    1
# 211    1
# 346    1
# 117    0
# 438    0
# 673    1
# 534    0
# 651    1
# 0      0
# 245    0
# 492    0
# 34     0
# 187    1
# 578    0
# 755    1
# 183    1
# 588    0
# 43     1
# 383    1
# 310    1
# 435    1
# 380    1
# 786    1
# 829    1
# 238    0
# 807    0
# 856    1
#       ..
# 266    0
# 40     0
# 523    1
# 561    0
# 165    1
# 548    0
# 376    1
# 526    1
# 681    1
# 877    0
# 788    1
# 202    0
# 477    0
# 665    0
# 15     1
# 587    1
# 863    0
# 728    0
# 835    1
# 398    0
# 834    0
# 554    1
# 31     1
# 557    0
# 683    0
# 319    1
# 225    0
# 331    0
# 283    1
# 350    0
# Name: Survived, Length: 295, dtype: int64

# %%
>>> from sklearn.ensemble import RandomForestClassifier #Run the model
>>> from sklearn.datasets import make_classification

clf = RandomForestClassifier(n_estimators=500,max_depth=20)
clf.fit(df_train, target_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=500, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
clf_probs = clf.predict_proba(df_test) 
#Get the prediction in probability

# %%
from sklearn import metrics
fpr_rt_lm, tpr_rt_lm, _ = metrics.roc_curve(target_test,clfr_probs[:, 1])
metrics.auc(fpr_rt_lm, tpr_rt_lm)
#Run RUC and get AUC value
# Out:
# 0.44368027982605412

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rt_lm, tpr_rt_lm, label='RT + LR')
metrics.auc(fpr_rt_lm, tpr_rt_lm)
#plot RUC
# Out:
# 0.44368027982605412
